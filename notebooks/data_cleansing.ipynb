# %%
import pandas as pd
import numpy as np

from datetime import datetime

# %%
# Declare Variable
today = pd.Timestamp(datetime.today())

# %%
# Read CSV
books_df = pd.read_csv(r"../data/03_Library Systembook.csv")

# Standardise column headers
books_df.columns = books_df.columns.str.title()

# Drops NaN records
books_df = books_df.dropna(subset=['Id', 'Books'])

# Convert Id fields to integers
for col in ['Id', 'Customer Id']:
    books_df[col] = books_df[col].astype(int)

# Capitalisew book titles
books_df['Books'] = books_df['Books'].str.title()

# Standardise dates
for col in ['Book Checkout', 'Book Returned']:
    books_df[col] = pd.to_datetime(books_df[col].str.strip('"'), format = '%d/%m/%Y', errors='coerce')

# Date validation

date_checks = [
    books_df['Book Checkout'].isna() & books_df['Book Returned'].isna(),
    (books_df['Book Checkout'] > today) | (books_df['Book Returned'] > today),
    books_df['Book Checkout'] > books_df['Book Returned']
]

date_flags = [
    'Invalid Dates',
    'Future Dates',
    'Checked Prceeding Return'
]

books_df['Date Validity'] = np.select(date_checks, date_flags, default='Valid Date')

books_df['Checkout Duration'] = np.where(
    books_df['Date Validity'] == 'Valid Date',
    (books_df['Book Returned'] - books_df['Book Checkout']).dt.days,
    None
)

display(books_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 39
#      29 date_flags = [
#      30     'Invalid Dates',
#      31     'Future Dates',
#      32     'Checked Prceeding Return'
#      33 ]
#      35 books_df['Date Validity'] = np.select(date_checks, date_flags, default='Valid Date')
#      37 books_df['Checkout Duration'] = np.where(
#      38     books_df['Date Validity'] == 'Valid Date',
# ---> 39     books_df['Book Returned'] - books_df['Book Checkout'].dt.days,
#      40     None
#      41 )
#      43 display(books_df)
#
# AttributeError: 'DatetimeProperties' object has no attribute 'days'

# %%
books_df = pd.read_csv(r"../data/03_Library Systembook.csv")

#Standardise column headers
books_df.columns = books_df.columns.str.title()

# Drops NaN records
books_df = books_df.dropna(subset=['Id', 'Books'])

# Convert Id fields to integers
for col in ['Id', 'Customer Id']:
    books_df[col] = books_df[col].astype(int)

# Capitalisew book titles
books_df['Books'] = books_df['Books'].str.title()

# Standardise dates
for col in ['Book Checkout', 'Book Returned']:
    books_df[col] = pd.to_datetime(books_df[col].str.strip('"'), format = '%d/%m/%Y', errors='coerce')

# Date validation

date_checks = [
    books_df['Book Checkout'].isna() & books_df['Book Returned'].isna(),
    books_df['Book Checkout'] > datetime.today() | books_df['Book Returned'] > datetime.today(),
    books_df['Book Checkout'] > books_df['Book Returned']
]

date_flags = [
    'Invalid Dates',
    'Future Dates',
    'Checked Prceeding Return'
]

books_df['Date Validity'] = np.select(date_checks, date_flags, default='Valid Date')

books_df['Checkout Duration'] = np.where(
    books_df['Date Validity'] == 'Valid Date',
    books_df['Book Returned'] - books_df['Book Checkout'],
    None
)

display(books_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 24
#      18     books_df[col] = pd.to_datetime(books_df[col].str.strip('"'), format = '%d/%m/%Y', errors='coerce')
#      20 # Date validation
#      22 date_checks = [
#      23     books_df['Book Checkout'].isna() & books_df['Book Returned'].isna(),
# ---> 24     books_df['Book Checkout'] > datetime.today() | books_df['Book Returned'] > datetime.today(),
#      25     books_df['Book Checkout'] > books_df['Book Returned']
#      26 ]
#      28 date_flags = [
#      29     'Invalid Dates',
#      30     'Future Dates',
#      31     'Checked Prceeding Return'
#      32 ]
#      34 books_df['Date Validity'] = np.select(date_checks, date_flags, default='Valid Date')
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arraylike.py:82, in OpsMixin.__ror__(self, other)
#      80 @unpack_zerodim_and_defer("__ror__")
#      81 def __ror__(self, other):
# ---> 82     return self._logical_method(other, roperator.ror_)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:5814, in Series._logical_method(self, other, op)
#    5811 lvalues = self._values
#    5812 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 5814 res_values = ops.logical_op(lvalues, rvalues, op)
#    5815 return self._construct_result(res_values, name=res_name)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:444, in logical_op(left, right, op)
#     440 rvalues = right
#     442 if should_extension_dispatch(lvalues, rvalues):
#     443     # Call the method on lvalues
# --> 444     res_values = op(lvalues, rvalues)
#     446 else:
#     447     if isinstance(rvalues, np.ndarray):
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\roperator.py:58, in ror_(left, right)
#      57 def ror_(left, right):
# ---> 58     return operator.or_(right, left)
#
# TypeError: unsupported operand type(s) for |: 'datetime.datetime' and 'DatetimeArray'

# %%
customers_df = pd.read_csv(r"../data/03_Library SystemCustomers.csv")

# Drops NaN records
customers_df = customers_df.dropna()

customers_df['Customer ID'] = customers_df['Customer ID'].astype(int)

# Standardise capitalisation
customers_df['Customer Name'] = customers_df['Customer Name'].str.title()

display(customers_df)
# Out:
#    Customer ID     Customer Name
# 0            1          Jane Doe
# 1            2        John Smith
# 2            3        Dan Reeves
# 4            5    William Holden
# 5            6     Jaztyn Forest
# 6            7     Jackie Irving
# 7            8  Matthew Stirling
# 8            9         Emory Ted
